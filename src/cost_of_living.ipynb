# %%
import requests

url = "https://cost-of-living-and-prices.p.rapidapi.com/prices"

querystring = {"city_name":"Antalya","country_name":"Turkey"}

headers = {
	"X-RapidAPI-Key": "2e80b6eda1mshc36ae8ca90d304ap13e719jsnfc088f44fdc0",
	"X-RapidAPI-Host": "cost-of-living-and-prices.p.rapidapi.com"
}

# response = requests.get(url, headers=headers, params=querystring)

# print(response.json())
# Out:
# {'city_id': 2094, 'city_name': 'Antalya', 'state_code': None, 'country_name': 'Turkey', 'exchange_rate': {'EUR': 0.94530377809561, 'AUD': 1.5785315840171819, 'USD': 1, 'CAD': 1.3880500368195823, 'CNY': 7.31730161145935, 'CZK': 23.31949566152831, 'DKK': 7.065037845236756, 'GBP': 0.8245383845325615, 'HKD': 7.820948120783355, 'JPY': 149.67198809673482, 'NZD': 1.7208744816190407, 'NOK': 11.22002134495931, 'RUB': 94.2036571912567, 'KRW': 1356.2199135803287, 'CHF': 0.9021856368653349, 'UAH': 36.44419351880824, 'SEK': 11.227716117713008}, 'exchange_rates_updated': {'date': '2023-10-27', 'timestamp': 1698441663}, 'prices': [{'good_id': 1, 'item_name': 'Price per square meter to Buy Apartment Outside of City Center', 'category_id': 1, 'category_name': 'Buy Apartment', 'min': 2531.74, 'avg': 4390.69, 'max': 6751.3, 'usd': {'min': '89.97', 'avg': '156.03', 'max': '239.92'}, 'measure': 'money', 'currency_code': 'TRY'}, {'good_id': 2, 'item_name': 'Price per square meter to Buy Apartment in City Center', 'category_id': 1, 'category_name': 'Buy Apartment', 'min': 4219.56, 'avg': 5962, 'max': 8397.94, 'usd': {'min': '149.95', 'avg': '211.87', 'max': '298.44'}, 'measure': 'money', 'currency_code': 'TRY'}, {'good_id': 3, 'item_name': 'International Primary School, Yearly for 1 Child', 'category_id': 2, 'category_name': 'Childcare', 'min': 22504.36, 'avg': 31593.96, 'max': 67513.17, 'usd': {'min': '799.75', 'avg': '1122.77', 'max': '2399.25'}, 'measure': 'money', 'currency_code': 'TRY'}, {'good_id': 4, 'item_name': 'Private Preschool or Kindergarten, Monthly for 1 Child', 'category_id': 2, 'category_name': 'Childcare', 'min': 787.62, 'avg': 1738.33, 'max': 2813.01, 'usd': {'min': '27.99', 'avg': '61.78', 'max': '99.97'}, 'measure': 'money', 'currency_code': 'TRY'}, {'good_id': 5, 'item_name': 'Pair of Jeans in a Chain Store Like George, H&M, Zara, etc.', 'category_id': 3, 'category_name': 'Clothing And Shoes', 'min': 101.25, 'avg': 253.17, 'max': 450.06, 'usd': {'min': '3.60', 'avg': '9.00', 'max': '15.99'}, 'measure': 'money', 'currency_code': 'TRY'}, {'good_id': 6, 'item_name': 'Pair of Leather Business Shoes', 'category_id': 3, 'category_name': 'Clothing And Shoes', 'min': 202.51, 'avg': 403.92, 'max': 605.33, 'usd': {'min': '7.20', 'avg': '14.35', 'max': '21.51'}, 'measure': 'money', 'currency_code': 'TRY'}, {'good_id': 7, 'item_name': 'Pair of Running Shoes, Mid-Range Price', 'category_id': 3, 'category_name': 'Clothing And Shoes', 'min': 337.57, 'avg': 514.82, 'max': 787.62, 'usd': {'min': '12.00', 'avg': '18.30', 'max': '27.99'}, 'measure': 'money', 'currency_code': 'TRY'}, {'good_id': 9, 'item_name': 'Apples, 1 kg', 'category_id': 4, 'category_name': 'Markets', 'min': 3.36, 'avg': 6.21, 'max': 9.06, 'usd': {'min': '0.12', 'avg': '0.22', 'max': '0.32'}, 'measure': 'money', 'currency_code': 'TRY'}, {'good_id': 10, 'item_name': 'Banana, 1 kg', 'category_id': 4, 'category_name': 'Markets', 'min': 7.89, 'avg': 14.93, 'max': 21.97, 'usd': {'min': '0.28', 'avg': '0.53', 'max': '0.78'}, 'measure': 'money', 'currency_code': 'TRY'}, {'good_id': 11, 'item_name': 'Beef Round or Equivalent Back Leg Red Meat, 1 kg ', 'category_id': 4, 'category_name': 'Markets', 'min': 58.47, 'avg': 76.59, 'max': 94.71, 'usd': {'min': '2.08', 'avg': '2.72', 'max': '3.37'}, 'measure': 'money', 'currency_code': 'TRY'}, {'good_id': 12, 'item_name': 'Bottle of Wine, Mid-Range Price', 'category_id': 4, 'category_name': 'Markets', 'min': 39.34, 'avg': 50.67, 'max': 78.77, 'usd': {'min': '1.40', 'avg': '1.80', 'max': '2.80'}, 'measure': 'money', 'currency_code': 'TRY'}, {'good_id': 13, 'item_name': 'Chicken Breasts, Boneless and Skinless, 1 kg', 'category_id': 4, 'category_name': 'Markets', 'min': 16.86, 'avg': 20.05, 'max': 28.1, 'usd': {'min': '0.60', 'avg': '0.71', 'max': '1.00'}, 'measure': 'money', 'currency_code': 'TRY'}, {'good_id': 14, 'item_name': 'Domestic Beer, 0.5 liter Bottle', 'category_id': 4, 'category_name': 'Markets', 'min': 11.24, 'avg': 14.43, 'max': 18. ...

# %%
# Out:
# {'city_id': 2094,
#  'city_name': 'Antalya',
#  'state_code': None,
#  'country_name': 'Turkey',
#  'exchange_rate': {'EUR': 0.94530377809561,
#   'AUD': 1.5785315840171819,
#   'USD': 1,
#   'CAD': 1.3880500368195823,
#   'CNY': 7.31730161145935,
#   'CZK': 23.31949566152831,
#   'DKK': 7.065037845236756,
#   'GBP': 0.8245383845325615,
#   'HKD': 7.820948120783355,
#   'JPY': 149.67198809673482,
#   'NZD': 1.7208744816190407,
#   'NOK': 11.22002134495931,
#   'RUB': 94.2036571912567,
#   'KRW': 1356.2199135803287,
#   'CHF': 0.9021856368653349,
#   'UAH': 36.44419351880824,
#   'SEK': 11.227716117713008},
#  'exchange_rates_updated': {'date': '2023-10-27', 'timestamp': 1698441663},
#  'prices': [{'good_id': 1,
#    'item_name': 'Price per square meter to Buy Apartment Outside of City Center',
#    'category_id': 1,
#    'category_name': 'Buy Apartment',
#    'min': 2531.74,
#    'avg': 4390.69,
#    'max': 6751.3,
#    'usd': {'min': '89.97', 'avg': '156.03', 'max': '239.92'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 2,
#    'item_name': 'Price per square meter to Buy Apartment in City Center',
#    'category_id': 1,
#    'category_name': 'Buy Apartment',
#    'min': 4219.56,
#    'avg': 5962,
#    'max': 8397.94,
#    'usd': {'min': '149.95', 'avg': '211.87', 'max': '298.44'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 3,
#    'item_name': 'International Primary School, Yearly for 1 Child',
#    'category_id': 2,
#    'category_name': 'Childcare',
#    'min': 22504.36,
#    'avg': 31593.96,
#    'max': 67513.17,
#    'usd': {'min': '799.75', 'avg': '1122.77', 'max': '2399.25'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 4,
#    'item_name': 'Private Preschool or Kindergarten, Monthly for 1 Child',
#    'category_id': 2,
#    'category_name': 'Childcare',
#    'min': 787.62,
#    'avg': 1738.33,
#    'max': 2813.01,
#    'usd': {'min': '27.99', 'avg': '61.78', 'max': '99.97'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 5,
#    'item_name': 'Pair of Jeans in a Chain Store Like George, H&M, Zara, etc.',
#    'category_id': 3,
#    'category_name': 'Clothing And Shoes',
#    'min': 101.25,
#    'avg': 253.17,
#    'max': 450.06,
#    'usd': {'min': '3.60', 'avg': '9.00', 'max': '15.99'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 6,
#    'item_name': 'Pair of Leather Business Shoes',
#    'category_id': 3,
#    'category_name': 'Clothing And Shoes',
#    'min': 202.51,
#    'avg': 403.92,
#    'max': 605.33,
#    'usd': {'min': '7.20', 'avg': '14.35', 'max': '21.51'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 7,
#    'item_name': 'Pair of Running Shoes, Mid-Range Price',
#    'category_id': 3,
#    'category_name': 'Clothing And Shoes',
#    'min': 337.57,
#    'avg': 514.82,
#    'max': 787.62,
#    'usd': {'min': '12.00', 'avg': '18.30', 'max': '27.99'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 9,
#    'item_name': 'Apples, 1 kg',
#    'category_id': 4,
#    'category_name': 'Markets',
#    'min': 3.36,
#    'avg': 6.21,
#    'max': 9.06,
#    'usd': {'min': '0.12', 'avg': '0.22', 'max': '0.32'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 10,
#    'item_name': 'Banana, 1 kg',
#    'category_id': 4,
#    'category_name': 'Markets',
#    'min': 7.89,
#    'avg': 14.93,
#    'max': 21.97,
#    'usd': {'min': '0.28', 'avg': '0.53', 'max': '0.78'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 11,
#    'item_name': 'Beef Round or Equivalent Back Leg Red Meat, 1 kg ',
#    'category_id': 4,
#    'category_name': 'Markets',
#    'min': 58.47,
#    'avg': 76.59,
#    'max': 94.71,
#    'usd': {'min': '2.08', 'avg': '2.72', 'max': '3.37'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 12,
#    'item_name': 'Bottle of Wine, Mid-Range Price',
#    'category_id': 4,
#    'category_name': 'Markets',
#    'min': 39.34,
#    'avg': 50.67,
#    'max': 78.77,
#    'usd': {'min': '1.40', 'avg': '1.80', 'max': '2.80'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 13,
#    'item_name': 'Chicken Breasts, Boneless and Skinless, 1 kg',
#    'category_id': 4,
#    'category_name': 'Markets',
#    'min': 16.86,
#    'avg': 20.05,
#    'max': 28.1,
#    'usd': {'min': '0.60', 'avg': '0.71', 'max': '1.00'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 14,
#    'item_name': 'Domestic Beer, 0.5 liter Bottle',
#    'category_id': 4,
#    'category_name': 'Markets',
#    'min': 11.24,
#    'avg': 14.43,
#    'max': 18.04,
#    'usd': {'min': '0.40', 'avg': '0.51', 'max': '0.64'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 15,
#    'item_name': 'Eggs, 12 pack',
#    'category_id': 4,
#    'category_name': 'Markets',
#    'min': 6.71,
#    'avg': 13.59,
#    'max': 20.47,
#    'usd': {'min': '0.24', 'avg': '0.48', 'max': '0.73'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 17,
#    'item_name': 'Lettuce, 1 head',
#    'category_id': 4,
#    'category_name': 'Markets',
#    'min': 2.26,
#    'avg': 4.7,
#    'max': 7.14,
#    'usd': {'min': '0.08', 'avg': '0.17', 'max': '0.25'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 18,
#    'item_name': 'Loaf of Fresh White Bread, 0.5 kg',
#    'category_id': 4,
#    'category_name': 'Markets',
#    'min': 1.68,
#    'avg': 2.68,
#    'max': 5.03,
#    'usd': {'min': '0.06', 'avg': '0.10', 'max': '0.18'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 19,
#    'item_name': 'Local Cheese, 1 kg',
#    'category_id': 4,
#    'category_name': 'Markets',
#    'min': 25.92,
#    'avg': 50.92,
#    'max': 75.92,
#    'usd': {'min': '0.92', 'avg': '1.81', 'max': '2.70'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 20,
#    'item_name': 'Milk, Regular,1 liter',
#    'category_id': 4,
#    'category_name': 'Markets',
#    'min': 3.94,
#    'avg': 6.54,
#    'max': 9.14,
#    'usd': {'min': '0.14', 'avg': '0.23', 'max': '0.32'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 21,
#    'item_name': 'Onion, 1 kg',
#    'category_id': 4,
#    'category_name': 'Markets',
#    'min': 2.18,
#    'avg': 5.37,
#    'max': 11.16,
#    'usd': {'min': '0.08', 'avg': '0.19', 'max': '0.40'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 22,
#    'item_name': 'Oranges, 1 kg',
#    'category_id': 4,
#    'category_name': 'Markets',
#    'min': 2.26,
#    'avg': 9.56,
#    'max': 16.86,
#    'usd': {'min': '0.08', 'avg': '0.34', 'max': '0.60'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 23,
#    'item_name': 'Pack of Cigarettes',
#    'category_id': 4,
#    'category_name': 'Markets',
#    'min': 19.13,
#    'avg': 20.22,
#    'max': 23.32,
#    'usd': {'min': '0.68', 'avg': '0.72', 'max': '0.83'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 24,
#    'item_name': 'Potato, 1 kg',
#    'category_id': 4,
#    'category_name': 'Markets',
#    'min': 1.68,
#    'avg': 3.77,
#    'max': 5.86,
#    'usd': {'min': '0.06', 'avg': '0.13', 'max': '0.21'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 25,
#    'item_name': 'White Rice, 1 kg',
#    'category_id': 4,
#    'category_name': 'Markets',
#    'min': 7.89,
#    'avg': 14.01,
#    'max': 20.55,
#    'usd': {'min': '0.28', 'avg': '0.50', 'max': '0.73'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 26,
#    'item_name': 'Tomato, 1 kg',
#    'category_id': 4,
#    'category_name': 'Markets',
#    'min': 2.26,
#    'avg': 5.96,
#    'max': 9.66,
#    'usd': {'min': '0.08', 'avg': '0.21', 'max': '0.34'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 27,
#    'item_name': 'Water, 1.5 liter Bottle',
#    'category_id': 4,
#    'category_name': 'Markets',
#    'min': 1.09,
#    'avg': 2.52,
#    'max': 3.95,
#    'usd': {'min': '0.04', 'avg': '0.09', 'max': '0.14'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 28,
#    'item_name': 'One bedroom apartment outside of city centre',
#    'category_id': 5,
#    'category_name': 'Rent Per Month',
#    'min': 562.64,
#    'avg': 1046.84,
#    'max': 1679.6,
#    'usd': {'min': '19.99', 'avg': '37.20', 'max': '59.69'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 29,
#    'item_name': 'One bedroom apartment in city centre',
#    'category_id': 5,
#    'category_name': 'Rent Per Month',
#    'min': 900.2,
#    'avg': 1403.03,
#    'max': 1905.86,
#    'usd': {'min': '31.99', 'avg': '49.86', 'max': '67.73'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 30,
#    'item_name': 'Three bedroom apartment outside of city centre',
#    'category_id': 5,
#    'category_name': 'Rent Per Month',
#    'min': 1125.19,
#    'avg': 1768.61,
#    'max': 3150.58,
#    'usd': {'min': '39.99', 'avg': '62.85', 'max': '111.96'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 31,
#    'item_name': 'Three bedroom apartment in city centre',
#    'category_id': 5,
#    'category_name': 'Rent Per Month',
#    'min': 1687.83,
#    'avg': 2475.62,
#    'max': 3375.65,
#    'usd': {'min': '59.98', 'avg': '87.98', 'max': '119.96'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 32,
#    'item_name': 'Cappuccino',
#    'category_id': 6,
#    'category_name': 'Restaurants',
#    'min': 8.98,
#    'avg': 14.01,
#    'max': 24.75,
#    'usd': {'min': '0.32', 'avg': '0.50', 'max': '0.88'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 33,
#    'item_name': 'Coca-Cola, 0.33 liter Bottle',
#    'category_id': 6,
#    'category_name': 'Restaurants',
#    'min': 3.36,
#    'avg': 5.79,
#    'max': 10.15,
#    'usd': {'min': '0.12', 'avg': '0.21', 'max': '0.36'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 34,
#    'item_name': 'Domestic Beer, 0.5 liter Draught',
#    'category_id': 6,
#    'category_name': 'Restaurants',
#    'min': 11.24,
#    'avg': 18.04,
#    'max': 28.1,
#    'usd': {'min': '0.40', 'avg': '0.64', 'max': '1.00'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 35,
#    'item_name': 'Imported Beer, 0.33 liter Bottle',
#    'category_id': 6,
#    'category_name': 'Restaurants',
#    'min': 13.51,
#    'avg': 21.39,
#    'max': 29.27,
#    'usd': {'min': '0.48', 'avg': '0.76', 'max': '1.04'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 36,
#    'item_name': 'McMeal at McDonalds or Alternative Combo Meal',
#    'category_id': 6,
#    'category_name': 'Restaurants',
#    'min': 28.1,
#    'avg': 29.28,
#    'max': 33.72,
#    'usd': {'min': '1.00', 'avg': '1.04', 'max': '1.20'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 37,
#    'item_name': 'Meal for 2 People, Mid-range Restaurant, Three-course',
#    'category_id': 6,
#    'category_name': 'Restaurants',
#    'min': 67.53,
#    'avg': 112.49,
#    'max': 202.51,
#    'usd': {'min': '2.40', 'avg': '4.00', 'max': '7.20'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 38,
#    'item_name': 'Meal in Inexpensive Restaurant',
#    'category_id': 6,
#    'category_name': 'Restaurants',
#    'min': 16.86,
#    'avg': 28.1,
#    'max': 50.67,
#    'usd': {'min': '0.60', 'avg': '1.00', 'max': '1.80'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 40,
#    'item_name': 'Average Monthly Net Salary, After Tax',
#    'category_id': 7,
#    'category_name': 'Salaries And Financing',
#    'min': 2897.66,
#    'avg': 3219.62,
#    'max': 3541.58,
#    'usd': {'min': '102.98', 'avg': '114.42', 'max': '125.86'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 42,
#    'item_name': 'Cinema ticket, 1 Seat',
#    'category_id': 8,
#    'category_name': 'Sports And Leisure',
#    'min': 18.04,
#    'avg': 24.75,
#    'max': 33.72,
#    'usd': {'min': '0.64', 'avg': '0.88', 'max': '1.20'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 43,
#    'item_name': 'Fitness Club, Monthly Fee for 1 Adult',
#    'category_id': 8,
#    'category_name': 'Sports And Leisure',
#    'min': 112.49,
#    'avg': 168.78,
#    'max': 281.28,
#    'usd': {'min': '4.00', 'avg': '6.00', 'max': '10.00'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 44,
#    'item_name': 'Tennis Court Rent, 1 Hour on Weekend',
#    'category_id': 8,
#    'category_name': 'Sports And Leisure',
#    'min': 28.1,
#    'avg': 48.49,
#    'max': 68.88,
#    'usd': {'min': '1.00', 'avg': '1.72', 'max': '2.45'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 45,
#    'item_name': 'Gasoline, 1 liter',
#    'category_id': 9,
#    'category_name': 'Transportation',
#    'min': 6.88,
#    'avg': 7.72,
#    'max': 8.56,
#    'usd': {'min': '0.24', 'avg': '0.27', 'max': '0.30'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 46,
#    'item_name': 'Monthly Pass, Regular Price',
#    'category_id': 9,
#    'category_name': 'Transportation',
#    'min': 90.01,
#    'avg': 122.31,
#    'max': 281.28,
#    'usd': {'min': '3.20', 'avg': '4.35', 'max': '10.00'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 47,
#    'item_name': 'One-way Ticket, Local Transport',
#    'category_id': 9,
#    'category_name': 'Transportation',
#    'min': 3.61,
#    'avg': 3.94,
#    'max': 4.53,
#    'usd': {'min': '0.13', 'avg': '0.14', 'max': '0.16'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 48,
#    'item_name': 'Taxi, price for 1 hour Waiting, Normal Tariff',
#    'category_id': 9,
#    'category_name': 'Transportation',
#    'min': 33.72,
#    'avg': 39.34,
#    'max': 67.53,
#    'usd': {'min': '1.20', 'avg': '1.40', 'max': '2.40'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 49,
#    'item_name': 'Taxi, price for 1 km, Normal Tariff',
#    'category_id': 9,
#    'category_name': 'Transportation',
#    'min': 3.36,
#    'avg': 4.53,
#    'max': 10.15,
#    'usd': {'min': '0.12', 'avg': '0.16', 'max': '0.36'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 50,
#    'item_name': 'Taxi Start, Normal Tariff',
#    'category_id': 9,
#    'category_name': 'Transportation',
#    'min': 4.53,
#    'avg': 6.71,
#    'max': 11.24,
#    'usd': {'min': '0.16', 'avg': '0.24', 'max': '0.40'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 52,
#    'item_name': 'Volkswagen Golf 1.4 90 KW Trendline (Or Equivalent New Car)',
#    'category_id': 9,
#    'category_name': 'Transportation',
#    'min': 168782.93,
#    'avg': 214916.93,
#    'max': 261050.93,
#    'usd': {'min': '5998.12', 'avg': '7637.61', 'max': '9277.10'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 53,
#    'item_name': 'Prepaid Mobile Tariff Local, price per 1 min, No Discounts or Plans',
#    'category_id': 10,
#    'category_name': 'Utilities Per Month',
#    'min': 0.42,
#    'avg': 0.92,
#    'max': 1.42,
#    'usd': {'min': '0.01', 'avg': '0.03', 'max': '0.05'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 54,
#    'item_name': 'Basic utilities for 85 square meter Apartment including Electricity, Heating or Cooling, Water and Garbage',
#    'category_id': 10,
#    'category_name': 'Utilities Per Month',
#    'min': 253.17,
#    'avg': 379.09,
#    'max': 562.64,
#    'usd': {'min': '9.00', 'avg': '13.47', 'max': '19.99'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 55,
#    'item_name': 'Internet, 60 Mbps or More, Unlimited Data, Cable/ADSL',
#    'category_id': 10,
#    'category_name': 'Utilities Per Month',
#    'min': 84.39,
#    'avg': 115.26,
#    'max': 251.92,
#    'usd': {'min': '3.00', 'avg': '4.10', 'max': '8.95'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 58,
#    'item_name': 'Water, 0.33 liter Bottle',
#    'category_id': 4,
#    'category_name': 'Markets',
#    'min': 1.09,
#    'avg': 2.26,
#    'max': 5.62,
#    'usd': {'min': '0.04', 'avg': '0.08', 'max': '0.20'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 64,
#    'item_name': 'Summer Dress in a Chain Store Like George, H&M, Zara, etc.',
#    'category_id': 3,
#    'category_name': 'Clothing And Shoes',
#    'min': 112.49,
#    'avg': 222.47,
#    'max': 419.86,
#    'usd': {'min': '4.00', 'avg': '7.91', 'max': '14.92'},
#    'measure': 'money',
#    'currency_code': 'TRY'},
#   {'good_id': 65,
#    'item_name': 'Mortgage Interest Rate in Percentages for 20 Years Fixed-Rate, Yearly, Fixed-Rate',
#    'category_id': 7,
#    'category_name': 'Salaries And Financing',
#    'min': 13.86,
#    'avg': 15.4,
#    'max': 16.94,
#    'measure': 'percent'},
#   {'good_id': 68,
#    'item_name': 'Imported Beer, 0.33 liter Bottle',
#    'category_id': 4,
#    'category_name': 'Markets',
#    'min': 13.51,
#    'avg': 17.87,
#    'max': 22.48,
#    'usd': {'min': '0.48', 'avg': '0.64', 'max': '0.80'},
#    'measure': 'money',
#    'currency_code': 'TRY'}],
#  'error': None}
